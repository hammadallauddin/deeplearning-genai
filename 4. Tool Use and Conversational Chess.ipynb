# %% [markdown]
# # Tool Use and Conversational Chess

# %% [markdown]
# ## Setup

# %%
from utils import get_gemini_api_key, get_gemini_model
GEMINI_API_KEY = get_gemini_api_key()
GEMINI_MODEL = get_gemini_model()
llm_config = {
    "model": GEMINI_MODEL,
    "api_key": GEMINI_API_KEY,
    "api_type": "google"
}

# %%
import chess
import chess.svg
from typing_extensions import Annotated

# %% [markdown]
# ## Initialize the chess board

# %%
board = chess.Board()

# %%
made_move = False

# %% [markdown]
# ## Define the needed tools
#
# ### 1. Tool for getting legal moves

# %%
def get_legal_moves(
    
) -> Annotated[str, "A list of legal moves in UCI format"]:
    return "Possible moves are: " + ",".join(
        [str(move) for move in board.legal_moves]
    )

# %% [markdown]
# ### 2. Tool for making a move on the board

# %%
def make_move(
    move: Annotated[str, "A move in UCI format."]
) -> Annotated[str, "Result of the move."]:
    move = chess.Move.from_uci(move)
    board.push_uci(str(move))
    global made_move
    made_move = True
    
    # Display the board.
    display(
        chess.svg.board(
            board,
            arrows=[(move.from_square, move.to_square)],
            fill={move.from_square: "gray"},
            size=200
        )
    )
    
    # Get the piece name.
    piece = board.piece_at(move.to_square)
    piece_symbol = piece.unicode_symbol()
    piece_name = (
        chess.piece_name(piece.piece_type).capitalize()
        if piece_symbol.isupper()
        else chess.piece_name(piece.piece_type)
    )
    return f"Moved {piece_name} ({piece_symbol}) from "\
    f"{chess.SQUARE_NAMES[move.from_square]} to "\
    f"{chess.SQUARE_NAMES[move.to_square]}."

# %% [markdown]
# ## Create agents
#
# You will create the player agents and a board proxy agents for the chess board.

# %%
from autogen import ConversableAgent

# %%
# Player white agent
player_white = ConversableAgent(
    name="Player White",
    system_message="You are a chess player and you play as white. "
    "First call get_legal_moves(), to get a list of legal moves. "
    "Then call make_move(move) to make a move.",
    llm_config=llm_config,
)

# %%
# Player black agent
player_black = ConversableAgent(
    name="Player Black",
    system_message="You are a chess player and you play as black. "
    "First call get_legal_moves(), to get a list of legal moves. "
    "Then call make_move(move) to make a move.",
    llm_config=llm_config,
)

# %%
def check_made_move(msg):
    global made_move
    if made_move:
        made_move = False
        return True
    else:
        return False

# %%
board_proxy = ConversableAgent(
    name="Board Proxy",
    llm_config=False,
    is_termination_msg=check_made_move,
    default_auto_reply="Please make a move.",
    human_input_mode="NEVER",
)

# %% [markdown]
# ## Register the tools
#
# A tool must be registered for the agent that calls the tool and the agent that executes the tool.

# %%
from autogen import register_function

# %%
for caller in [player_white, player_black]:
    register_function(
        get_legal_moves,
        caller=caller,
        executor=board_proxy,
        name="get_legal_moves",
        description="Get legal moves.",
    )
    
    register_function(
        make_move,
        caller=caller,
        executor=board_proxy,
        name="make_move",
        description="Call this tool to make a move.",
    )

# %%
player_black.llm_config["tools"]
# Out:
# [{'type': 'function',
#   'function': {'description': 'Get legal moves.',
#    'name': 'get_legal_moves',
#    'parameters': {'type': 'object', 'properties': {}, 'required': []}}},
#  {'type': 'function',
#   'function': {'description': 'Call this tool to make a move.',
#    'name': 'make_move',
#    'parameters': {'type': 'object',
#     'properties': {'move': {'type': 'string',
#       'description': 'A move in UCI format.'}},
#     'required': ['move']}}}]

# %% [markdown]
# ## Register the nested chats
#
# Each player agent will have a nested chat with the board proxy agent to
# make moves on the chess board.

# %%
player_white.register_nested_chats(
    trigger=player_black,
    chat_queue=[
        {
            "sender": board_proxy,
            "recipient": player_white,
            "summary_method": "last_msg",
        }
    ],
)

player_black.register_nested_chats(
    trigger=player_white,
    chat_queue=[
        {
            "sender": board_proxy,
            "recipient": player_black,
            "summary_method": "last_msg",
        }
    ],
)

# %% [markdown]
# ## Start the Game
#
# The game will start with the first message.

# %% [markdown]
# <p style="background-color:#ECECEC; padding:15px; "> <b>Note:</b> In this lesson, you will use GPT 4 for better results. Please note that the lesson has a quota limit. If you want to explore the code in this lesson further, we recommend trying it locally with your own API key.

# %% [markdown]
# **Note**: You might get a slightly different moves than what's shown in the video.

# %%
board = chess.Board()

chat_result = player_black.initiate_chat(
    player_white,
    message="Let's play chess! Your move.",
    max_turns=2,
)
# Out:
# Player Black (to Player White):
#
# Let's play chess! Your move.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Board Proxy (to Player White):
#
# Let's play chess! Your move.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)
#     274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\grpc\_interceptor.py:331, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
# --> 331 return call.result(), call
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\grpc\_channel.py:438, in _InactiveRpcError.result(self, timeout)
#     437 """See grpc.Future.result."""
# --> 438 raise self
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\grpc\_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\grpc\_channel.py:1173, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 state, call = self._blocking(
#    1171     request, timeout, metadata, credentials, wait_for_ready, compression
#    1172 )
# -> 1173 return _end_unary_response_blocking(state, call, True, None)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\grpc\_channel.py:990, in _end_unary_response_blocking(state, call, with_call, deadline)
#     989     return state.response
# --> 990 raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.RESOURCE_EXHAUSTED
# 	details = "You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 35.895696428s."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:142.250.203.10:443 {grpc_message:"You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 35.895696428s.", grpc_status:8}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ResourceExhausted                         Traceback (most recent call last)
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\oai\gemini.py:122, in GeminiClient.create(self, params)
#     121 try:
# --> 122     response = chat.send_message(gemini_messages[-1].parts[0].text, stream=stream)
#     123 except InternalServerError:
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\generativeai\generative_models.py:578, in ChatSession.send_message(self, content, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     574     raise ValueError(
#     575         "Invalid configuration: The chat functionality does not support `candidate_count` greater than 1."
#     576     )
# --> 578 response = self.model.generate_content(
#     579     contents=history,
#     580     generation_config=generation_config,
#     581     safety_settings=safety_settings,
#     582     stream=stream,
#     583     tools=tools_lib,
#     584     tool_config=tool_config,
#     585     request_options=request_options,
#     586 )
#     588 self._check_response(response=response, stream=stream)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     330 else:
# --> 331     response = self._client.generate_content(
#     332         request,
#     333         **request_options,
#     334     )
#     335     return generation_types.GenerateContentResponse.from_response(response)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\gapic_v1\method.py:128, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     126     kwargs["compression"] = compression
# --> 128 return wrapped_func(*args, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_base.py:216, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     211     final_exc, source_exc = exc_factory_fn(
#     212         error_list,
#     213         RetryFailureReason.NON_RETRYABLE_ERROR,
#     214         original_timeout,
#     215     )
# --> 216     raise final_exc from source_exc
#     217 if on_error_fn is not None:
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\google\api_core\grpc_helpers.py:57, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      56 except grpc.RpcError as exc:
# ---> 57     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 35.895696428s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 20
# }
# , retry_delay {
#   seconds: 35
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[32], line 3
#       1 board = chess.Board()
# ----> 3 chat_result = player_black.initiate_chat(
#       4     player_white,
#       5     message="Let's play chess! Your move.",
#       6     max_turns=2,
#       7 )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:984, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#     982         if msg2send is None:
#     983             break
# --> 984         self.send(msg2send, recipient, request_reply=True, silent=silent)
#     985 else:
#     986     self._prepare_chat(recipient, clear_history)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:632, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     630 valid = self._append_oai_message(message, "assistant", recipient)
#     631 if valid:
# --> 632     recipient.receive(message, self, request_reply, silent)
#     633 else:
#     634     raise ValueError(
#     635         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     636     )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:792, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     790 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     791     return
# --> 792 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     793 if reply is not None:
#     794     self.send(reply, sender, silent=silent)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:1921, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    1919     continue
#    1920 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 1921     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    1922     if final:
#    1923         return reply
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:389, in ConversableAgent._summary_from_nested_chats(chat_queue, recipient, messages, sender, config)
#     387 if not chat_to_run:
#     388     return True, None
# --> 389 res = initiate_chats(chat_to_run)
#     390 return True, res[-1].summary
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\chat.py:190, in initiate_chats(chat_queue)
#     188     __post_carryover_processing(chat_info)
#     189     sender = chat_info["sender"]
# --> 190     chat_res = sender.initiate_chat(**chat_info)
#     191     finished_chats.append(chat_res)
#     192 return finished_chats
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:991, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#     989     else:
#     990         msg2send = self.generate_init_message(message, **kwargs)
# --> 991     self.send(msg2send, recipient, silent=silent)
#     992 summary = self._summarize_chat(
#     993     summary_method,
#     994     summary_args,
#     995     recipient,
#     996     cache=cache,
#     997 )
#     998 for agent in [self, recipient]:
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:632, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     630 valid = self._append_oai_message(message, "assistant", recipient)
#     631 if valid:
# --> 632     recipient.receive(message, self, request_reply, silent)
#     633 else:
#     634     raise ValueError(
#     635         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     636     )
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:792, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     790 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     791     return
# --> 792 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     793 if reply is not None:
#     794     self.send(reply, sender, silent=silent)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:1921, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    1919     continue
#    1920 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 1921     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    1922     if final:
#    1923         return reply
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:1287, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1285 if messages is None:
#    1286     messages = self._oai_messages[sender]
# -> 1287 extracted_response = self._generate_oai_reply_from_client(
#    1288     client, self._oai_system_message + messages, self.client_cache
#    1289 )
#    1290 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\agentchat\conversable_agent.py:1306, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1303         all_messages.append(message)
#    1305 # TODO: #1143 handle token limit exceeded error
# -> 1306 response = llm_client.create(
#    1307     context=messages[-1].pop("context", None),
#    1308     messages=all_messages,
#    1309     cache=cache,
#    1310 )
#    1311 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1313 if extracted_response is None:
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\oai\client.py:638, in OpenAIWrapper.create(self, **config)
#     636 try:
#     637     request_ts = get_current_ts()
# --> 638     response = client.create(params)
#     639 except APITimeoutError as err:
#     640     logger.debug(f"config {i} timed out", exc_info=True)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\autogen\oai\gemini.py:131, in GeminiClient.create(self, params)
#     129     time.sleep(delay)
#     130 except Exception as e:
# --> 131     raise RuntimeError(f"Google GenAI exception occurred while calling Gemini API: {e}")
#     132 else:
#     133     # `ans = response.text` is unstable. Use the following code instead.
#     134     ans: str = chat.history[-1].parts[0].text
#
# RuntimeError: Google GenAI exception occurred while calling Gemini API: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 35.895696428s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 20
# }
# , retry_delay {
#   seconds: 35
# }
# ]

# %% [markdown]
# ## Adding a fun chitchat to the game!

# %%
player_white = ConversableAgent(
    name="Player White",
    system_message="You are a chess player and you play as white. "
    "First call get_legal_moves(), to get a list of legal moves. "
    "Then call make_move(move) to make a move. "
    "After a move is made, chitchat to make the game fun.",
    llm_config=llm_config,
)

# %%
player_black = ConversableAgent(
    name="Player Black",
    system_message="You are a chess player and you play as black. "
    "First call get_legal_moves(), to get a list of legal moves. "
    "Then call make_move(move) to make a move. "
    "After a move is made, chitchat to make the game fun.",
    llm_config=llm_config,
)

# %%
for caller in [player_white, player_black]:
    register_function(
        get_legal_moves,
        caller=caller,
        executor=board_proxy,
        name="get_legal_moves",
        description="Get legal moves.",
    )

    register_function(
        make_move,
        caller=caller,
        executor=board_proxy,
        name="make_move",
        description="Call this tool to make a move.",
    )

player_white.register_nested_chats(
    trigger=player_black,
    chat_queue=[
        {
            "sender": board_proxy,
            "recipient": player_white,
            "summary_method": "last_msg",
            "silent": True,
        }
    ],
)

player_black.register_nested_chats(
    trigger=player_white,
    chat_queue=[
        {
            "sender": board_proxy,
            "recipient": player_black,
            "summary_method": "last_msg",
            "silent": True,
        }
    ],
)

# %%
board = chess.Board()

chat_result = player_black.initiate_chat(
    player_white,
    message="Let's play chess! Your move.",
    max_turns=2,
)

# %% [markdown]
# **Note:**
# To add human input to this game, add **human_input_mode="ALWAYS"** for both player agents.
